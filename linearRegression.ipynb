# %%
import sklearn

# %%
import sklearn;
sklearn.show_versions()
# Out:
# System:
#     python: 3.12.3 (tags/v3.12.3:f6650f9, Apr  9 2024, 14:05:25) [MSC v.1938 64 bit (AMD64)]
# executable: C:\Users\HP\AppData\Local\Programs\Python\Python312\python.exe
#    machine: Windows-10-10.0.19045-SP0
#
# Python dependencies:
#       sklearn: 1.4.2
#           pip: 24.0
#    setuptools: None
#         numpy: 1.26.4
#         scipy: 1.13.0
#        Cython: None
#        pandas: 2.2.2
#    matplotlib: 3.9.0
#        joblib: 1.4.2
# threadpoolctl: 3.5.0
#
# Built with OpenMP: True
#
# threadpoolctl info:
#        user_api: openmp
#    internal_api: openmp
#     num_threads: 8
#          prefix: vcomp
#        filepath: C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\.libs\vcomp140.dll
#         version: None
#
#        user_api: blas
#    internal_api: openblas
#     num_threads: 8
#          prefix: libopenblas
# ...

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# %%
print(housing.data.shape)
# Out:
# (20640, 8)

# %%
print(housing.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
print(housing.target)
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %%
print(housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
import pandas as pd

# %%
hos=pd.DataFrame(housing.data)
hos.head()
# Out:
#         0     1         2         3       4         5      6       7
# 0  8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1  8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2  7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3  5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4  3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25

# %%
hos['price']=housing.target
x=hos.drop('price',axis=1)
y=hos['price']
print(hos.head())
print(x)
print(y)
# Out:
#         0     1         2         3       4         5      6       7  price
# 0  8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23  4.526
# 1  8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22  3.585
# 2  7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24  3.521
# 3  5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25  3.413
# 4  3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25  3.422
#             0     1         2         3       4         5      6       7
# 0      8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2      7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...       ...   ...       ...       ...     ...       ...    ...     ...
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (16512, 8)
# (4128, 8)
# (16512,)
# (4128,)

# %%
lm.fit(x_train,y_train)
y_pred=lm.predict(x_test)
# Ensure y_test and y_pred are pandas Series or numpy arrays
y_test = pd.Series(y_test)
y_pred = pd.Series(y_pred)

# Align y_test and y_pred to ensure they have the same shape and indices
y_test, y_pred = y_test.align(y_pred, join='inner')

# Check the shapes to confirm they are the same
print(y_test.shape)
print(y_pred.shape)

# Plot the true prices against the predicted prices
plt.scatter(y_test, y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.show()
print(lm.predict(x.head()))
# Out:
# (804,)
# (804,)
# [4.14350447 3.99155653 3.67093882 3.25356492 2.40821509]

# %%
import seaborn as sns
import numpy as np
# Ensure y_test and y_pred are pandas Series or numpy arrays
y_test = pd.Series(y_test)
y_pred = pd.Series(y_pred)

# Align y_test and y_pred to ensure they have the same shape and indices
y_test, y_pred = y_test.align(y_pred, join='inner')

# Calculate the difference
delta_y = y_test - y_pred

# Plot the distribution of differences
sns.set_style('whitegrid')
sns.kdeplot(np.array(delta_y), bw_method=0.5)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.set_style('whitegrid')
sns.kdeplot(np.array(y_pred),bw_method=0.5)
plt.show()

# %%
sns.set_style('whitegrid')
sns.kdeplot(np.array(y_test),bw_method=0.5)
plt.show()

# %%
hos.head(1)

# %%
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import numpy as np
lm=MLPRegressor(learning_rate_init=0.001,solver="lbfgs",max_iter=500)
lm.fit(x_train,y_train)

y_pred=lm.predict(x_train)

plt.scatter(y_train,y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()
print(lm.predict(x.head()))
lm
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [4.10056154 3.81423628 3.7107963  3.15267421 2.29582174]
# MLPRegressor(max_iter=500, solver='lbfgs')
